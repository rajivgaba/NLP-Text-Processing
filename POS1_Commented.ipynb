# %% [markdown]
# ## Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### How do we identify product features?
# <img src = "./images/keywords.png">

# %%
sent1 = "I loved the screen on this phone."
sent2 = "The battery life on this phone is great."
sent3 = "The speakers are pathetic."

# %% [markdown]
# ### Lets do a POS parse and see if we can figure out some patterns.

# %%
# import Spacy and load model.
import spacy

model = spacy.load("en_core_web_sm")

# %%
# Print the PoS tag of sent1

tokens = model(sent1)

for token in tokens:
    print(token.text, token.pos_, token.tag_)
# Out:
# I PRON PRP
# loved VERB VBD
# the DET DT
# screen NOUN NN
# on ADP IN
# this DET DT
# phone NOUN NN
# . PUNCT .

# %%
# Print the PoS tag of sent2

tokens = model(sent2)

for token in tokens:
    print(token.text, token.pos_, token.tag_)
# Out:
# The DET DT
# battery NOUN NN
# life NOUN NN
# on ADP IN
# this DET DT
# phone NOUN NN
# is AUX VBZ
# great ADJ JJ
# . PUNCT .

# %%
# Print the PoS tag of sent3

tokens = model(sent3)

for token in tokens:
    print(token.text, token.pos_, token.tag_)
# Out:
# The DET DT
# speakers NOUN NNS
# are AUX VBP
# pathetic ADJ JJ
# . PUNCT .

# %% [markdown]
# #### **Product features such as `screen`, `battery`, `speaker` have a POS tag of NOUN**

# %% [markdown]
# ## Summary
# - Product features such as `screen`, `battery` and `speaker` have a POS tag of Noun
# - If we can find the frequency count of all the nouns in our data, then by looking at top-n nouns we can find out what product features people are talking about
# - Check hypothesis on a real world dataset

# %%
samsung_file = "/content/Samsung.txt"

# %%
con = open(samsung_file, 'r', encoding='utf-8')
samsung_reviews = con.read()
con.close()

# %%
len(samsung_reviews.split('\n'))
# Out:
# 46355

# %%
review1 = samsung_reviews.split('\n')[0]
review1
# Out:
# "I feel so LUCKY to have found this used (phone to us & not used hard at all), phone on line from someone who upgraded and sold this one. My Son liked his old one that finally fell apart after 2.5+ years and didn't want an upgrade!! Thank you Seller, we really appreciate it & your honesty re: said used phone.I recommend this seller very highly & would but from them again!!"

# %%
tokens = model(review1)

for token in tokens:
    print(token.text, token.pos_, token.tag_)
# Out:
# I PRON PRP
# feel VERB VBP
# so ADV RB
# LUCKY ADJ JJ
# to PART TO
# have AUX VB
# found VERB VBN
# this PRON DT
# used ADJ JJ
# ( PUNCT -LRB-
# phone NOUN NN
# to ADP IN
# us PRON PRP
# & CCONJ CC
# not PART RB
# used VERB VBN
# hard ADV RB
# at ADV RB
# all ADV RB
# ) PUNCT -RRB-
# , PUNCT ,
# phone NOUN NN
# on ADP IN
# line NOUN NN
# from ADP IN
# someone PRON NN
# who PRON WP
# upgraded VERB VBD
# and CCONJ CC
# sold VERB VBD
# this DET DT
# one NOUN NN
# . PUNCT .
# My PRON PRP$
# Son PROPN NNP
# liked VERB VBD
# his PRON PRP$
# old ADJ JJ
# one NOUN NN
# that PRON WDT
# finally ADV RB
# fell VERB VBD
# apart ADV RB
# after ADP IN
# 2.5 NUM CD
# + NUM CD
# years NOUN NNS
# and CCONJ CC
# did AUX VBD
# n't PART RB
# want VERB VB
# an DET DT
# upgrade NOUN NN
# ! PUNCT .
# ! PUNCT .
# Thank VERB VBP
# you PRON PRP
# Seller PROPN NNP
# , PUNCT ,
# we PRON PRP
# really ADV RB
# appreciate VERB VBP
# it PRON PRP
# & CCONJ CC
# your PRON PRP$
# honesty NOUN NN
# re NOUN NN
# : PUNCT :
# said VERB VBD
# used VERB VBN
# phone NOUN NN
# . PUNCT .
# I PRON PRP
# recommend VERB VBP
# this DET DT
# seller NOUN NN
# very ADV RB
# highly ADV RB
# & CCONJ CC
# would AUX MD
# but CCONJ CC
# from ADP IN
# them PRON PRP
# again ADV RB
# ! PUNCT .
# ! PUNCT .

# %%
# Convert each token into its lemma and identify the PoS tags.
pos = []
lemma = []
text = []
for tok in model(review1):
    pos.append(tok.pos_)
    lemma.append(tok.lemma_)
    text.append(tok.text)

# Convert the data into a dataframe object.
nlp_table = pd.DataFrame({'text':text,'lemma':lemma,'pos':pos})
nlp_table.head()
# Out:
#     text  lemma   pos
# 0      I      I  PRON
# 1   feel   feel  VERB
# 2     so     so   ADV
# 3  LUCKY  lucky   ADJ
# 4     to     to  PART

# %%
nlp_table['text'].value_counts().sort_values(ascending=False).head()
# Out:
# text
# !        4
# used     3
# this     3
# phone    3
# &        3
# Name: count, dtype: int64

# %%
nlp_table[nlp_table['pos'] == 'NOUN']['lemma'].value_counts().sort_values(ascending=False).head()
# Out:
# lemma
# phone      3
# one        2
# line       1
# year       1
# upgrade    1
# Name: count, dtype: int64

# %%
nlp_table[(nlp_table['pos'] == 'NOUN') ]['lemma'].value_counts().sort_values(ascending=False)
# Out:
# lemma
# phone      3
# one        2
# line       1
# year       1
# upgrade    1
# honesty    1
# re         1
# seller     1
# Name: count, dtype: int64

# %%
nlp_table.shape
# Out:
# (86, 3)

# %%
from tqdm import tqdm


i = 0
pos = []
lemma = []
text = []
nouns = []

for review in tqdm(samsung_reviews.split("\n")[0:1000]):
    doc = model(review)
    for tok in doc:
        if tok.pos_=="NOUN":
            nouns.append(tok.lemma_.lower())
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 77.19it/s]

# %%
pd.Series(nouns).value_counts().head(5)
# Out:
# phone      1214
# time         92
# battery      89
# price        87
# screen       86
# Name: count, dtype: int64

# %%
# Convert the data into a dataframe object.
nlp_table = pd.DataFrame({'text':text,'lemma':lemma,'pos':pos})
nlp_table.head()
# Out:
#     text  lemma   pos
# 0      I      I  PRON
# 1   feel   feel  VERB
# 2     so     so   ADV
# 3  LUCKY  lucky   ADJ
# 4     to     to  PART

# %%
nlp_table.shape
# Out:
# (41187, 3)

# %%
nlp_table[(nlp_table['pos'] == 'NOUN') ]['lemma'].value_counts().sort_values(ascending=False)
# Out:
# lemma
# phone          1214
# time             90
# battery          89
# price            87
# screen           86
#                ...
# touchscreen       1
# 4.4.2             1
# behaviour         1
# taping            1
# cel               1
# Name: count, Length: 1274, dtype: int64

# %%
nlp=spacy.load('en_core_web_sm',disable=['parser','ner'])

# %%
from tqdm import tqdm
i = 0
pos = []
lemma = []
text = []
nouns = []

for review in tqdm(samsung_reviews.split("\n")):
    doc = nlp(review)
    for tok in doc:
        if tok.pos_=="NOUN":
            nouns.append(tok.lemma_.lower())
# Out:
# 100%|██████████| 46355/46355 [04:22<00:00, 176.46it/s]

# %%
pd.Series(nouns).value_counts().head(5)
# Out:
# phone      43512
# battery     4344
# product     3958
# time        3833
# screen      3789
# Name: count, dtype: int64

# %%
import re

# %%
s1 = "The battery was great"
pattern = '\w+\sbattery\s\w+'

# %%
re.findall('\w+\sbattery\s\w+', s1)[0].split(' ')[0]
# Out:
# 'The'

# %%
re.findall('\w+\sbattery\s\w+', s1)[0].split(' ')[-1]
# Out:
# 'was'

# %%
re.findall(pattern, s1)[0].split(' ')[0]
# Out:
# 'The'

# %%
prefixes_suffixes = re.findall(pattern, samsung_reviews)

# %%
prefixes_suffixes
# Out:
# ['that battery life',
#  'The battery was',
#  'great battery life',
#  'removable battery or',
#  'the battery in',
#  'The battery was',
#  'the battery is',
#  'Excellent battery life',
#  'the battery off',
#  'the battery goes',
#  'defective battery in',
#  'The battery is',
#  'and battery lasts',
#  'the battery as',
#  'the battery nor',
#  'replaceable battery and',
#  'The battery lasts',
#  'Long battery life',
#  'the battery is',
#  'Long battery life',
#  'The battery life',
#  'The battery is',
#  'long battery life',
#  'charged battery I',
#  'spare battery ready',
#  'The battery is',
#  'The battery that',
#  'the battery is',
#  'the battery drain',
#  'except battery had',
#  'the battery gets',
#  'The battery is',
#  'Amazing battery life',
#  'The battery lasts',
#  'the battery display',
#  'the battery lasted',
#  'the battery went',
#  'the battery was',
#  'the battery doesn',
#  'the battery was',
#  'The battery life',
#  'Awesome battery life',
#  'Improved battery life',
#  'drains battery faster',
#  'of battery life',
#  'Long battery life',
#  'the battery and',
#  'phones battery from',
#  'sealed battery compartment',
#  'great battery life',
#  'the battery and',
#  'the battery out',
#  'locking battery compartment',
#  'Great battery life',
#  'good battery life',
#  'the battery life',
#  'the battery power',
#  'the battery lasts',
#  'B2100 battery panel',
#  'AC battery charger',
#  'DC battery charge',
#  's battery while',
#  'Long battery life',
#  'a battery that',
#  'the battery is',
#  '5 battery bars',
#  'The battery lasts',
#  'the battery is',
#  'better battery and',
#  'better battery then',
#  'and battery are',
#  'the battery for',
#  'good battery life',
#  'with battery and',
#  'great battery life',
#  'of battery life',
#  'strong battery which',
#  'the battery life',
#  'the battery already',
#  'excellent battery life',
#  'excellent battery life',
#  'smartphone battery died',
#  'Good battery life',
#  'the battery life',
#  'The battery is',
#  'decent battery life',
#  'the battery life',
#  'the battery life',
#  'extended battery that',
#  'this battery is',
#  'the battery and',
#  'for battery life',
#  'the battery recharging',
#  'with battery and',
#  'great battery life',
#  'losing battery charge',
#  'the battery and',
#  'its battery life',
#  'the battery recharging',
#  'the battery life',
#  'extended battery life',
#  'The battery is',
#  'the battery saver',
#  'great battery life',
#  'the battery for',
#  'perfect battery life',
#  'poor battery life',
#  'The battery can',
#  'conserve battery life',
#  'for battery use',
#  'the battery and',
#  'extended battery for',
#  'the battery incluided',
#  'removable battery is',
#  'the battery lasts',
#  'the battery life',
#  'with battery life',
#  'large battery pack',
#  'the battery does',
#  'long battery life',
#  'The battery can',
#  'poor battery life',
#  'laptop battery today',
#  'great battery life',
#  'The battery is',
#  'wrong battery was',
#  'Replaceable battery is',
#  'similar battery life',
#  'similar battery life',
#  'average battery life',
#  'the battery life',
#  'The battery life',
#  'The battery life',
#  'the battery isn',
#  'the battery life',
#  'vs battery autonomy',
#  'good battery life',
#  'No battery access',
#  'the battery so',
#  'great battery life',
#  'great battery life',
#  'good battery life',
#  'a5 battery is',
#  'excellent battery life',
#  'the battery life',
#  'the battery so',
#  'the battery faster',
#  'long battery life',
#  'the battery lasts',
#  'Good battery endurance',
#  'the battery life',
#  'better battery life',
#  'mAh battery with',
#  'the battery life',
#  'the battery lasts',
#  'the battery will',
#  'The battery dies',
#  'the battery life',
#  'The battery dies',
#  'Great battery life',
#  'replaceable battery unlike',
#  'capacity battery compared',
#  'the battery life',
#  'the battery that',
#  'the battery sustains',
#  'standby battery if',
#  'the battery life',
#  'the battery to',
#  'any battery issues',
#  'the battery runs',
#  'resolve battery life',
#  'the battery life',
#  'the battery I',
#  'removable battery is',
#  'as battery life',
#  'drinks battery juice',
#  'my battery us',
#  'the battery would',
#  'that battery problem',
#  'day battery life',
#  'the battery life',
#  'the battery will',
#  'The battery life',
#  'The battery life',
#  'about battery life',
#  'second battery from',
#  'with battery saver',
#  'ultra battery saver',
#  'but battery life',
#  'so battery life',
#  'Fantastic battery life',
#  'the battery life',
#  'this battery doesn',
#  'full battery usually',
#  'in battery death',
#  'second battery and',
#  'drinks battery juice',
#  'my battery us',
#  'the battery would',
#  'that battery problem',
#  'the battery life',
#  'the battery I',
#  'the battery runs',
#  'capacity battery compared',
#  'the battery life',
#  'The battery life',
#  'portable battery charger',
#  'phone battery life',
#  'and battery upgrade',
#  'Great battery life',
#  'the battery to',
#  'day battery life',
#  'the battery life',
#  'replaceable battery unlike',
#  'removable battery is',
#  'as battery life',
#  'Fantastic battery life',
#  'the battery life',
#  'this battery doesn',
#  'full battery usually',
#  'in battery death',
#  'second battery and',
#  'any battery issues',
#  'the battery that',
#  'the battery sustains',
#  'standby battery if',
#  'the battery life',
#  'second battery from',
#  'with battery saver',
#  'ultra battery saver',
#  'but battery life',
#  'so battery life',
#  'better battery life',
#  'drinks battery juice',
#  'my battery us',
#  'the battery would',
#  'that battery problem',
#  'The battery life',
#  'the battery runs',
#  'the battery life',
#  'the battery I',
#  'the battery to',
#  'The battery life',
#  'portable battery charger',
#  'and battery upgrade',
#  'about battery life',
#  'resolve battery life',
#  'Great battery life',
#  'capacity battery compared',
#  'the battery life',
#  'The battery life',
#  'the battery isn',
#  'the battery life',
#  'similar battery life',
#  'similar battery life',
#  'average battery life',
#  'the battery life',
#  'The battery life',
#  'The battery life',
#  'the battery isn',
#  'the battery life',
#  'The battery life',
#  'The battery life',
#  'similar battery life',
#  'similar battery life',
#  'average battery life',
#  'the battery life',
#  'The battery life',
#  'similar battery life',
#  'similar battery life',
#  'average battery life',
#  'the battery life',
#  'the battery isn',
#  'the battery life',
#  'The battery life',
#  'Samsung battery cover',
#  'as battery won',
#  'orginal battery of',
#  'the battery life',
#  'the battery is',
#  'but battery could',
#  'the battery life',
#  'the battery life',
#  'the battery life',
#  'the battery life',
#  'good battery life',
#  'the battery life',
#  'the battery does',
#  'good battery life',
#  'the battery to',
#  'the battery performance',
#  'the battery last',
#  'cheap battery but',
#  'the battery life',
#  'the battery a',
#  'the battery runs',
#  'the battery every',
#  'the battery drains',
#  'Drains battery faster',
#  'the battery will',
#  'My battery last',
#  'daily battery life',
#  'the battery saving',
#  'The battery could',
#  'the battery life',
#  'the battery finished',
#  'the battery life',
#  'the battery life',
#  'set battery percentages',
#  'long battery life2',
#  'the battery can',
#  'biggest battery drain',
#  'much battery is',
#  'the battery is',
#  'the battery and',
#  'Average battery life',
#  'in battery consumption',
#  'sometimes battery is',
#  'saving battery life',
#  'terrible battery life',
#  'poor battery life',
#  'the battery and',
#  'the battery lasts',
#  'with battery and',
#  'good battery life',
#  'the battery duration',
#  'the battery life',
#  'the battery was',
#  'The battery is',
#  's battery this',
#  'The battery lasts',
#  'The battery lasts',
#  'The battery needs',
#  'the battery gets',
#  'the battery life',
#  'also battery efficient',
#  'The battery life',
#  'have battery life',
#  'the battery which',
#  'the battery after',
#  'the battery pops',
#  'about battery life',
#  'the battery and',
#  'the battery life',
#  'the battery out',
#  'a battery managing',
#  'the battery should',
#  'major battery issues',
#  'the battery life',
#  'better battery life',
#  'the battery for',
#  'better battery life',
#  'the battery out',
#  'the battery last',
#  'phones battery drained',
#  'fair battery life',
#  'The battery life',
#  'particularly battery draining',
#  'the battery SUCKS',
#  'good battery life',
#  'Decent battery lifeThin',
#  'good battery life',
#  'the battery life',
#  'the battery life',
#  'the battery life',
#  'the battery life',
#  'with battery and',
#  'good battery life',
#  'the battery does',
#  'the battery life',
#  'original battery last',
#  'the battery needs',
#  'the battery and',
#  'Average battery life',
#  'in battery consumption',
#  'sometimes battery is',
#  'Drains battery faster',
#  'the battery will',
#  'My battery last',
#  'The battery could',
#  'the battery life',
#  'doing battery life',
#  'and battery saving',
#  'on battery life',
#  'the battery cover',
#  'the battery begins',
#  'the battery drains',
#  'the battery life',
#  'set battery percentages',
#  'the battery life',
#  'the battery life',
#  'saving battery life',
#  'terrible battery life',
#  'poor battery life',
#  'the battery and',
#  'the battery duration',
#  'the battery life',
#  'the battery holds',
#  'the battery life',
#  'the battery life',
#  'poor battery life',
#  'The battery life',
#  'the battery still',
#  'the battery would',
#  'good battery life',
#  'the battery to',
#  'the battery performance',
#  'the battery last',
#  'the battery is',
#  'phones battery aren',
#  'the battery finished',
#  'long battery life2',
#  'the battery can',
#  'biggest battery drain',
#  'much battery is',
#  'the battery is',
#  'good battery life',
#  'The battery seems',
#  'the battery life',
#  'the battery life',
#  'good battery life',
#  'better battery life',
#  'the battery\nExcelente',
#  'good battery life',
#  'good battery life',
#  'better battery life',
#  'the battery on',
#  'removable battery will',
#  'the battery anymore',
#  'the battery turns',
#  'the battery runs',
#  'that battery lifetime',
#  'the battery doesn',
#  'the battery life',
#  'the battery drains',
#  'The battery is',
#  'the battery life',
#  'but battery last',
#  'the battery will',
#  'that battery is',
#  'the battery and',
#  'and battery but',
#  'the battery wont',
#  'the battery was',
#  'the battery drained',
#  's battery didn',
#  'was battery life',
#  'about battery life',
#  'average battery usage',
#  'hrs battery reserve',
#  'the battery to',
#  'minimal battery drain',
#  'say battery life',
#  'phone battery nearly',
#  'the battery life',
#  'the battery life',
#  'Its battery life',
#  'but battery life',
#  'but battery last',
#  'the battery will',
#  'that battery is',
#  'the battery and',
#  'and battery but',
#  'the battery turns',
#  'the battery life',
#  'the battery life',
#  'The battery works',
#  'the battery life',
#  'the battery life',
#  'great battery life',
#  'are battery drainers',
#  'BEST battery life',
#  'the battery bad',
#  'the battery does',
#  'the battery died',
#  'the battery and',
#  'new battery because',
#  'the battery didn',
#  'great battery life',
#  'the battery is',
#  'it battery last',
#  'better battery life',
#  'great battery long',
#  'Amazing battery life',
#  'the battery so',
#  'better battery savings',
#  'in battery consumption',
#  'the battery is',
#  'The battery is',
#  'it battery last',
#  'Long battery life',
#  'good battery life',
#  'the battery life',
#  'charged battery on',
#  'The battery number',
#  'the battery life',
#  'the battery life',
#  'high battery life',
#  'holds battery very',
#  'the battery earbuds',
#  'good battery life',
#  'and battery with',
#  'good battery life',
#  'good battery life',
#  'the battery life',
#  'the battery life',
#  'high battery life',
#  'the battery life',
#  'and battery with',
#  'good battery life',
#  'charged battery on',
#  'The battery number',
#  'the battery earbuds',
#  'holds battery very',
#  'good battery life',
#  'the battery life',
#  'high battery life',
#  'the battery life',
#  'charged battery on',
#  'The battery number',
#  'good battery life',
#  'the battery earbuds',
#  'holds battery very',
#  'and battery with',
#  'the battery life',
#  'the battery life',
#  'high battery life',
#  'good battery life',
#  'Amazing battery life',
#  'better battery savings',
#  'the battery and',
#  'the battery so',
#  'The battery is',
#  'great battery life',
#  'in battery consumption',
#  'Long battery life',
#  'new battery because',
#  'the battery didn',
#  'it battery last',
#  'the battery so',
#  'Long battery life',
#  'is battery doesn',
#  'The battery life',
#  'additional battery to',
#  'far battery life',
#  'Extended battery since',
#  'The battery last',
#  'expect battery life',
#  'The battery last',
#  'expect battery life',
#  'The battery is',
#  'The battery is',
#  'The battery is',
#  'The battery is',
#  'The battery is',
#  'The battery lasts',
#  'great battery life',
#  'the battery performance',
#  'the battery life',
#  'my battery is',
#  'standby battery time',
#  'of battery despite',
#  'great battery life',
#  'the battery performance',
#  'the battery life',
#  'my battery is',
#  'standby battery time',
#  'of battery despite',
#  'The battery lasts',
#  'great battery life',
#  'the battery performance',
#  'the battery life',
#  'my battery is',
#  'standby battery time',
#  'of battery despite',
#  'The battery lasts',
#  'great battery life',
#  'the battery performance',
#  'phone battery runs',
#  'phone battery runs',
#  'phone battery runs',
#  'phone battery runs',
#  'phone battery runs',
#  'good battery life',
#  'The battery life',
#  'the battery works',
#  'the battery is',
#  'Good battery life',
#  'The battery life',
#  'good battery life',
#  'great battery on',
#  'The battery life',
#  'great battery on',
#  'the battery works',
#  'the battery is',
#  'The battery life',
#  'Good battery life',
#  'good battery life',
#  'good battery life',
#  'good battery life',
#  'The battery life',
#  'great battery on',
#  'the battery works',
#  'the battery is',
#  'great battery on',
#  'good battery life',
#  'good battery life',
#  'the battery easily',
#  'the battery would',
#  'the battery seems',
#  'phone battery die',
#  'your battery life',
#  'your battery life',
#  'the battery would',
#  'the battery seems',
#  'phone battery die',
#  'the battery easily',
#  'the battery easily',
#  'the battery would',
#  'the battery seems',
#  'phone battery die',
#  'your battery life',
#  'the battery would',
#  'the battery seems',
#  'phone battery die',
#  'The battery seems',
#  'the battery life',
#  'and battery life',
#  'the battery life',
#  'Removeable battery better',
#  'great battery life',
#  'my battery left',
#  'the battery problems',
#  'the battery life',
#  'the battery last',
#  'removable battery and',
#  'The battery lasts',
#  'a battery that',
#  'long battery duration',
#  'the battery and',
#  'and battery runs',
#  'the battery as',
#  'BEST battery life',
#  'better battery life',
#  'and battery life',
#  'great battery life',
#  'My battery lasts',
#  'replacable battery and',
#  'extra battery so',
#  'percent battery life',
#  'The battery doesn',
#  'the battery was',
#  'to battery life',
#  'drains battery to',
#  'long battery life',
#  'the battery is',
#  'the battery charged',
#  'the battery and',
#  'and battery runs',
#  'the battery as',
#  'BEST battery life',
#  'better battery life',
#  'replacable battery and',
#  'the battery life',
#  'better battery life',
#  'the battery slowly',
#  'The battery lasts',
#  'the battery did',
#  'the battery still',
#  'long battery life',
#  'GREAT battery life',
#  'the battery did',
#  'the battery slowly',
#  'The battery lasts',
#  'better battery life',
#  'GREAT battery life',
#  'the battery still',
#  'long battery life',
#  'the battery did',
#  'The battery lasts',
#  'a battery that',
#  'extra battery so',
#  'percent battery life',
#  'great battery life',
#  'my battery left',
#  'and battery life',
#  'the battery charged',
#  'the battery last',
#  'removable battery and',
#  'the battery and',
#  'and battery runs',
#  'the battery as',
#  'BEST battery life',
#  'better battery life',
#  'long battery life',
#  'the battery is',
#  'the battery life',
#  'great battery life',
#  'My battery lasts',
#  'and battery life',
#  'the battery problems',
#  'the battery life',
#  'the battery was',
#  'long battery duration',
#  'drains battery to',
#  'The battery doesn',
#  'replacable battery and',
#  'Removeable battery better',
#  'great battery life',
#  'my battery left',
#  'to battery life',
#  'and battery life',
#  'great battery life',
#  'My battery lasts',
#  'The battery charge',
#  'drains battery to',
#  'the battery problems',
#  'the battery life',
#  'replacable battery and',
#  'the battery life',
#  'and battery life',
#  'Removeable battery better',
#  'to battery life',
#  'the battery last',
#  'removable battery and',
#  'great battery life',
#  'my battery left',
#  'long battery life',
#  'the battery is',
#  'The battery doesn',
#  'great battery life',
#  'My battery lasts',
#  'and battery life',
#  'the battery charged',
#  'The battery lasts',
#  'a battery that',
#  'long battery duration',
#  'extra battery so',
#  'percent battery life',
#  'long battery life',
#  'the battery is',
#  'the battery and',
#  'and battery runs',
#  'the battery as',
#  'BEST battery life',
#  'better battery life',
#  'The battery life',
#  'The battery life',
#  'The battery life',
#  'outstanding battery life',
#  'outstanding battery life',
#  'outstanding battery life',
#  'the battery life',
#  'the battery lasts',
#  'the battery starts',
#  'removable battery is',
#  'the battery is',
#  'and battery life',
#  'The battery life',
#  'long battery life',
#  'and battery life',
#  'choose battery life',
#  'The battery life',
#  'damaged battery when',
#  'Excelente\nbattery runs',
#  'The battery was',
#  'the battery lasts',
#  'Excelente\nbattery runs',
#  'the battery starts',
#  'removable battery is',
#  'the battery is',
#  'The battery was',
#  'long battery life',
#  'and battery life',
#  'choose battery life',
#  'the battery life',
#  'the battery lasts',
#  'and battery life',
#  'The battery life',
#  'the battery lasts',
#  'and battery life',
#  'the battery life',
#  'poor battery life',
#  'long battery life',
#  'the battery holds',
#  'The battery life',
#  'damaged battery when',
#  'and battery life',
#  'the battery life',
#  'The battery life',
#  'damaged battery when',
#  'the battery life',
#  'the battery lasts',
#  'The battery life',
#  'the battery died',
#  'the battery last',
#  'same battery life',
#  'replaceable battery and',
#  'bigger battery if',
#  's battery charge',
#  'The battery life',
#  'The battery life',
#  'of battery power',
#  'short battery life',
#  'the battery usage',
#  'the battery last',
#  'nice battery last',
#  'its battery power',
#  'The battery life',
#  'good battery life',
#  'the battery cover',
#  'the battery pops',
#  'the battery overheats',
#  'The battery lasts',
#  '2nd battery in',
#  'the battery yet',
#  'the battery is',
#  'The battery was',
#  'new battery but',
#  'new battery and',
#  'The battery life',
#  'new battery in',
#  'poor battery that',
#  'and battery was',
#  'replaceable battery and',
#  'terrible battery life',
#  'The battery would',
#  'the battery lasts',
#  'the battery life',
#  'the battery is',
#  'new battery but',
#  'new battery and',
#  'The battery life',
#  'new battery in',
#  'poor battery that',
#  'replaceable battery and',
#  'The battery was',
#  'The battery would',
#  'the battery lasts',
#  'new battery but',
#  'new battery and',
#  'The battery life',
#  'terrible battery life',
#  'the battery is',
#  'and battery was',
#  'the battery life',
#  'a battery hog',
#  'the battery lasts',
#  'the battery will',
#  'the battery will',
#  'the battery removal',
#  'outstanding battery life',
#  'the battery power',
#  'the battery because',
#  'the battery away',
#  'Great battery life',
#  'Zerolemon battery and',
#  'the battery has',
#  'insane battery life',
#  'Great battery life',
#  'in battery life',
#  'the battery to',
#  'The battery life',
#  's battery is',
#  'bigger battery but',
#  'a battery that',
#  'excessive battery consumption',
#  'the battery life',
#  'my battery and',
#  'the battery lasts',
#  'the battery fairly',
#  'the battery is',
#  'The battery life',
#  'the battery last',
#  'the battery though',
#  'good battery backup',
#  'Incredible battery stamina',
#  'long battery life',
#  'and battery life',
#  'the battery lasts',
#  'average battery life',
#  'about battery life',
#  'The battery life',
#  'AMP battery than',
#  'a battery doesn',
#  'some battery power',
#  'long battery life',
#  'GREAT battery life',
#  'the battery life',
#  'even battery life',
#  'Good battery life',
#  'good battery backup',
#  'the battery or',
#  'original battery though',
#  'old battery that',
#  'original battery though',
#  'old battery that',
#  'the battery or',
#  'replaceable battery and',
#  'the battery is',
#  'the battery is',
#  'new battery free',
#  'The battery arrived',
#  'new battery in',
#  'replacement battery which',
#  'The battery on',
#  'fantastic battery life',
#  'charged battery whenever',
#  'external battery and',
#  'new battery as',
#  'great battery life',
#  'Great battery life',
#  'the battery is',
#  'The battery that',
#  'the battery right',
#  'the battery dies',
#  'it battery life',
#  'The battery couldn',
#  'charged battery whenever',
#  'external battery and',
#  'fantastic battery life',
#  'replaceable battery and',
#  'the battery when',
#  '2016Removable battery and',
#  'the battery of',
#  'with battery life',
#  'the battery life',
#  'the battery lasts',
#  'a battery problem',
#  'replace battery or',
#  'increased battery life',
#  'are battery hogs',
#  'change battery within',
#  'stock battery is',
#  'ion battery is',
#  'great battery life',
#  'unremovable battery was',
#  'and battery is',
#  'your battery goes',
#  'me battery kinda',
#  'the battery life',
#  'the battery if',
#  'best battery life',
#  'the battery is',
#  'The battery will',
#  'portable battery on',
#  'removable battery and',
#  'better battery performance',
#  'the battery is',
#  'The battery life',
#  'my battery in',
#  '4 battery life',
#  'Good battery life',
#  'good battery backup',
#  'same battery life',
#  'the battery is',
#  'The battery will',
#  'portable battery on',
#  'better battery performance',
#  'the battery is',
#  'The battery life',
#  'my battery in',
#  '4 battery life',
#  'removable battery and',
#  'the battery if',
#  'best battery life',
#  'and battery is',
#  'your battery goes',
#  'ion battery is',
#  'me battery kinda',
#  'the battery life',
#  'great battery life',
#  'unremovable battery was',
#  'better battery performance',
#  'the battery is',
#  'The battery will',
#  'portable battery on',
#  'stock battery is',
#  'removable battery and',
#  '10000mah battery for',
#  'and battery last',
#  'your battery NOR',
#  'their battery and',
#  'the battery is',
#  'and battery with',
#  'the battery and',
#  'your battery NOR',
#  'their battery and',
#  'and battery last',
#  '10000mah battery for',
#  'the battery is',
#  'the battery life',
#  'the battery since',
#  'the battery surprisingly',
#  'the battery are',
#  'the battery drain',
#  'with battery life',
#  'the battery degrades',
#  'hemorrhages battery charge',
#  'its battery life',
#  ...]
